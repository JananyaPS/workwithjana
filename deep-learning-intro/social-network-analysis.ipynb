# %% [markdown]
# # SOCIAL NETWORK ANALYSIS:

# %% [markdown]
# Social Network Analysis (SNA), also known as network science, is a general study of the social network utilizing network and graph theory concepts. It explores the behaviour of individuals at the micro-level, their relationships (social structure) at the macro level, and the connection between the two.

# %% [markdown]
# LIBRARIES USED:

# %% [markdown]
# NETWORKX:

# %% [markdown]
# NetworkX is a Python library for the creation, manipulation, and study of complex networks (or graphs). It provides an extensive collection of tools for the analysis of network data.

# %% [markdown]
# MATPLOTLIB:

# %% [markdown]
# Matplotlib is a Python plotting library used to create static, animated, and interactive visualizations in Python. It can be used in combination with other libraries like NumPy and Pandas for data manipulation and analysis

# %% [markdown]
# ZACHARY KARATE CLUB DATASET:

# %% [markdown]
# Zachary's karate club is a social network of a university karate club, described in the paper "An Information Flow Model for Conflict and Fission in Small Groups" by Wayne W. Zachary.
# A social network of a karate club was studied by Wayne W. Zachary for a period of three years from 1970 to 1972. The network captures 34 members of a karate club, documenting links between pairs of members who interacted outside the club

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Load the Zachary's Karate Club dataset
G = nx.karate_club_graph()

# Print basic statistics
print("Basic Network Statistics:")
print("Number of nodes:", G.number_of_nodes())
print("Number of edges:", G.number_of_edges())

# Visualize the graph
plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=300)
plt.title("Zachary's Karate Club Network")
plt.show()
# Out:
# Basic Network Statistics:
# Number of nodes: 34
# Number of edges: 78

# %% [markdown]
# MEASURES USED:

# %% [markdown]
# DEGREE CENTRALITY:

# %% [markdown]
# Degree centrality measures the number of connections a node has. In a directed network, it can be divided into in-degree centrality (number of incoming connections) and out-degree centrality (number of outgoing connections).

# %% [markdown]
# CLOSENESS CENTRALITY:

# %% [markdown]
# Closeness centrality measures how close a node is to all other nodes in the network.

# %% [markdown]
# BETWEENESS CENTRALITY:

# %% [markdown]
# Betweenness centrality measures the extent to which a node lies on paths between other nodes. It is calculated as the number of shortest paths that pass through a node.

# %%
# Calculate and print centrality measures
print("\nCentrality Measures:")
degree_centrality = nx.degree_centrality(G)
closeness_centrality = nx.closeness_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)

print("Degree Centrality:", degree_centrality)
print("Closeness Centrality:", closeness_centrality)
print("Betweenness Centrality:", betweenness_centrality)

# Detect communities
communities = list(nx.community.greedy_modularity_communities(G))
print("\nCommunities:", communities)
# Out:
# Centrality Measures:
# Degree Centrality: {0: 0.48484848484848486, 1: 0.2727272727272727, 2: 0.30303030303030304, 3: 0.18181818181818182, 4: 0.09090909090909091, 5: 0.12121212121212122, 6: 0.12121212121212122, 7: 0.12121212121212122, 8: 0.15151515151515152, 9: 0.06060606060606061, 10: 0.09090909090909091, 11: 0.030303030303030304, 12: 0.06060606060606061, 13: 0.15151515151515152, 14: 0.06060606060606061, 15: 0.06060606060606061, 16: 0.06060606060606061, 17: 0.06060606060606061, 18: 0.06060606060606061, 19: 0.09090909090909091, 20: 0.06060606060606061, 21: 0.06060606060606061, 22: 0.06060606060606061, 23: 0.15151515151515152, 24: 0.09090909090909091, 25: 0.09090909090909091, 26: 0.06060606060606061, 27: 0.12121212121212122, 28: 0.09090909090909091, 29: 0.12121212121212122, 30: 0.12121212121212122, 31: 0.18181818181818182, 32: 0.36363636363636365, 33: 0.5151515151515151}
# ...
